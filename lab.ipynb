# %%
from generating import generator_gran, generator_large
from collecting import collector
from plotting import plotter
from averaging import mean_average

from sorting_techniques import pysort
sortObj = pysort.Sorting()

# %%
def algo_callback(arg): # Implement the algorithm you want to test inside this function!
  sortObj.mergeSort(arg)

# %%
results_set = []
for i in range(10): # Change this number for sample size!
  set = generator_gran(2000)
  results = collector(algo_callback, set)
  results_set.append(results)

# %%
average_results = mean_average(*results_set)

# %%
plotter(average_results)
